# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# import zipfile
# import os

# zip_path = '/content/drive/MyDrive/Synthia/synthia.zip'
# extract_path = '/content/drive/MyDrive/Synthia'  # Where you want to extract

# with zipfile.ZipFile(zip_path, 'r') as zip_ref:
#     zip_ref.extractall(extract_path)

# %%
# !pip install langgraph langchain pandas ctgan python-dotenv google-generativeai serpapi kaggle requests langchain-community langchain-groq scikit-learn numpy

# %%
# !pip install -U langchain-community langchain-core langchain-experimental

# %%
# %cd /content/drive/MyDrive/Synthia
# Out:
# /content/drive/MyDrive/Synthia

# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
# !python /content/drive/MyDrive/Synthia/main.py

# %%
# !ls /content/drive/MyDrive/Synthia
# Out:
# agents	 data	   main.py  __pycache__       synthia.ipynb  untitled
# app2.py  graph.py  modules  requirements.txt  synthia.zip
# app.py	 logs.txt  output   state.py	      test.py

# %%
# !pip install graphviz

# %%
pip install --upgrade langgraph

# %%
# from langgraph.graph import StateGraph
# from typing import TypedDict
# import pandas as pd
# import IPython.display
# from langgraph.graph.graph import draw_graph

# # -------- Import your agents -------- #
# from agents.sample_gen_agent import generate_sample_data
# from agents.gap_det_agent import clean_data
# from agents.gan_agent import generate_tabular_data_ctgan
# from agents.eda_agent import check_quality
# from agents.feed_agent import decide_regeneration

# # -------- Define the AppState -------- #
# class AppState(TypedDict):
#     df: pd.DataFrame
#     synthetic_df: pd.DataFrame
#     quality_report: dict
#     regenerate_count: int
#     decision: str
#     prompt: str

# # -------- Define all step functions -------- #
# def sample_gen(state: AppState) -> AppState:
#     prompt_or_path = state.get("prompt", None)
#     df = generate_sample_data(prompt_or_path)
#     return {**state, "df": df}

# def clean_step(state: AppState) -> AppState:
#     cleaned_df = clean_data(state["df"])
#     return {**state, "df": cleaned_df}

# def gan_step(state: AppState) -> AppState:
#     synthetic_df = generate_tabular_data_ctgan(state["df"], epochs=10)
#     current_count = state.get("regenerate_count", 0)
#     new_count = current_count + 1 if state.get("decision") == "regenerate" else current_count
#     return {**state, "synthetic_df": synthetic_df, "regenerate_count": new_count}

# def eda_step(state: AppState) -> AppState:
#     quality = check_quality(state["synthetic_df"])
#     return {**state, "quality_report": quality}

# def feedback_step(state: AppState) -> AppState:
#     decision = decide_regeneration(state["quality_report"])
#     return {**state, "decision": decision}

# def decide_next_step(state: AppState) -> str:
#     decision = state.get("decision", "end")
#     if decision == "regenerate" and state.get("regenerate_count", 0) < 1:
#         return "regenerate"
#     return "end"

# # -------- Build the graph -------- #
# graph = StateGraph(AppState)

# # Add nodes
# graph.add_node("sample", sample_gen)
# graph.add_node("clean", clean_step)
# graph.add_node("gan", gan_step)
# graph.add_node("eda", eda_step)
# graph.add_node("feedback", feedback_step)

# # Add edges
# graph.set_entry_point("sample")
# graph.add_edge("sample", "clean")
# graph.add_edge("clean", "gan")
# graph.add_edge("gan", "eda")
# graph.add_edge("eda", "feedback")

# # Conditional edge from feedback
# graph.add_conditional_edges(
#     "feedback",
#     decide_next_step,
#     {
#         "regenerate": "gan",
#         "end": "__end__"
#     }
# )

# # Compile graph into app
# app = graph.compile()

# # -------- Visualize the graph -------- #
# # Display graph if in notebook
# IPython.display.display(graph.get_graph().draw())

# # Optional: Save graph as PNG file
# # graph.get_graph().draw().render("stategraph_diagram", format="png", cleanup=True)

# %%
# !pip install langgraph langchain pandas ctgan python-dotenv google-generativeai \
             serpapi kaggle requests langchain-community langchain-groq \
             scikit-learn numpy

# %%
# !pip install streamlit pyngrok

# %%
# !ngrok config add-authtoken cr_2mGzhIaS6yooGuFxq5rhRPuMkDy

# %%
# # 🔧 Install required packages
# !pip install streamlit pyngrok --quiet

# # ✅ Save Streamlit app code (only do if not already saved)
# with open("app.py", "w") as f:
#     f.write("""
# import streamlit as st
# import pandas as pd
# from graph import app as synthia_app

# st.set_page_config(page_title="SYNTHIA - Synthetic Data Generator", layout="wide")
# st.title("🧬 SYNTHIA: AI-powered Synthetic Data Generator")

# input_type = st.radio("Choose your input method:", ["Text Prompt", "Upload Dataset"])
# n_samples = st.number_input("📊 Number of synthetic records to generate", min_value=10, max_value=5000, step=10, value=200)

# if input_type == "Text Prompt":
#     user_prompt = st.text_area("📝 Enter your analysis prompt", placeholder="e.g. Generate a dataset of fitness apps...")
#     if st.button("Run SYNTHIA"):
#         with st.spinner("⏳ Generating synthetic data..."):
#             try:
#                 final_state = synthia_app.invoke({
#                     "regenerate_count": 0,
#                     "prompt": user_prompt,
#                     "df": None,
#                     "n_samples": int(n_samples)
#                 })
#                 st.success("✅ Completed!")
#                 st.write("### 🔎 EDA and Quality Report")
#                 st.markdown(final_state.get("quality_insights", "No insights found."))
#                 st.write("### 🧪 Synthetic Dataset Preview")
#                 st.dataframe(final_state.get("synthetic_df"))
#             except Exception as e:
#                 st.error(f"❌ Error: {e}")

# elif input_type == "Upload Dataset":
#     uploaded_file = st.file_uploader("📁 Upload your CSV file", type=["csv"])
#     if uploaded_file is not None:
#         try:
#             df = pd.read_csv(uploaded_file)
#             st.write("### 👁️ Original Data Preview", df.head())
#             if st.button("Run SYNTHIA on Uploaded Data"):
#                 with st.spinner("⏳ Processing..."):
#                     final_state = synthia_app.invoke({
#                         "regenerate_count": 0,
#                         "prompt": None,
#                         "df": df,
#                         "n_samples": int(n_samples)
#                     })
#                 st.success("✅ Done!")
#                 st.write("### 🔍 EDA and Quality Report")
#                 st.markdown(final_state.get("quality_insights", "No insights found."))
#                 st.write("### 🧪 Synthetic Dataset Preview")
#                 st.dataframe(final_state.get("synthetic_df"))
#         except Exception as e:
#             st.error(f"❌ Failed to read uploaded CSV: {e}")

# if 'final_state' in locals() and final_state.get("synthetic_df") is not None:
#     csv = final_state["synthetic_df"].to_csv(index=False).encode('utf-8')
#     st.download_button("⬇️ Download Synthetic Data", data=csv, file_name='synthetic_data.csv', mime='text/csv')

# """)

# # ✅ Authenticate ngrok (only once per user)
# import os
# os.environ["NGROK_AUTH_TOKEN"] = "2mGzhIaS6yooGuFxq5rhRPuMkDy_5HFgtp186z4sBnsAXKPv3"

# %%
# !pip install streamlit-extras uuid

# %%
# !pip install streamlit pyngrok --quiet



# Start Streamlit in background with logs
# !streamlit run app.py --server.port 8501 > logs.txt 2>&1 &
# !sleep 3 && tail -n 20 logs.txt

# Connect ngrok
from pyngrok import ngrok, conf
conf.get_default().auth_token = "2mGzhIaS6yooGuFxq5rhRPuMkDy_5HFgtp186z4sBnsAXKPv3"
public_url = ngrok.connect(8501)
print("🌐 Public URL:", public_url)
# Out:
# ...
#
# 2025-07-09 15:24:24.800 Port 8501 is already in use
# WARNING:pyngrok.process.ngrok:t=2025-07-09T15:24:27+0000 lvl=warn msg="failed to start tunnel" pg=/api/tunnels id=9cda2f45c6761842 err="failed to start tunnel: Your account may not run more than 3 tunnels over a single ngrok agent session.\nThe tunnels already running on this session are:\ntn_2zdiw5VlOJtSWrr9HS2xEKsHUyO, tn_2zdpKGezULgeZikSkMLPhX3W4KP, tn_2zdx0WscSce8jRZoL7gVgdE1FDG\n\r\n\r\nERR_NGROK_324\r\n"
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# /usr/local/lib/python3.11/dist-packages/pyngrok/ngrok.py in api_request(url, method, data, params, timeout, auth)
#     626     try:
# --> 627         response = urlopen(request, encoded_data, timeout)
#     628         response_data = response.read().decode("utf-8")
#
# ...

# %%
# !pip install streamlit pyngrok --quiet

# from pyngrok import conf, ngrok
# import time

# # Set your ngrok authtoken (only once per account)
# conf.get_default().auth_token = "2mGzhIaS6yooGuFxq5rhRPuMkDy_5HFgtp186z4sBnsAXKPv3"

# # Kill previous tunnels if running
# ngrok.kill()

# # Start Streamlit in background
# !streamlit run app.py --server.port 8501 --server.enableXsrfProtection false --server.enableCORS false &

# # Wait for Streamlit to start
# time.sleep(5)

# # Create public URL
# public_url = ngrok.connect(8501)
# print("🔗 Public URL:", public_url)

# %%
# !pip install streamlit pyngrok --quiet

from pyngrok import conf, ngrok
import time

# Set your ngrok authtoken (only once per account)
conf.get_default().auth_token = "2mGzhIaS6yooGuFxq5rhRPuMkDy_5HFgtp186z4sBnsAXKPv3"

# Kill previous tunnels if running
ngrok.kill()

# Start Streamlit in background
# !streamlit run app2.py --server.port 8501 --server.enableXsrfProtection false --server.enableCORS false &

# Wait for Streamlit to start
time.sleep(5)

# Create public URL
public_url = ngrok.connect(8501)
print("🔗 Public URL:", public_url)
# Out:
# ...
#
# 2025-07-09 16:59:30.165 Port 8501 is already in use
# 🔗 Public URL: NgrokTunnel: "https://e5c7eeaac9eb.ngrok-free.app" -> "http://localhost:8501"

# %%
! wget -q -O - ipv4.icanhazip.com

# %%
# Out:
# 	zip warning: name not matched: /content/drive/MyDrive/SynthiaSynthia
#
# zip error: Nothing to do! (try: zip -r /content/drive/MyDrive/SynthiaSynthia/synthia_app.zip . -i /content/drive/MyDrive/SynthiaSynthia)

# %%
# !ls /content/drive/MyDrive/
# Out:
#  1_B.Tech_AI_and_DS_R20.pdf
#  2.docx
#  3.docx
# '4 (1).docx'
#  4.docx
#  5.docx
#  715336-Tax.pdf
#  angry_2.png
#  BEEE_Mech_Unit-1.pdf
#  c74e474fa7d9eb692e0aa64570411ffc.jpg
# 'Carbon Trading.pptx'
# 'Centac NEET.pdf'
#  centac.pdf
#  Churn_ann
#  Classroom
# 'Code Lifesavers '
#  Code_Lifesavers.pptx
# 'Colab Notebooks'
# 'Copy of Python For Data Science - - Unit 5 - Week 3.pdf'
# 'cpm sih (1).pptx'
# 'cpm sih.pptx'
#  customers_indian2.gsheet
# 'DAA UNIT-1_.pdf'
#  data
# 'Dbms_Janani[1].docx'
# 'Doc1 (1).docx'
#  Doc1.docx
#  Doc2.docx
#  Doc3.docx
#  Doc5.docx
# 'download (1).jpeg'
#  download.jpeg
#  DSA
#  DSCA242273587.pdf
#  e0c5093b-2a81-473a-917d-f36a17a1f9ca.pdf
#  emotion
#  GAN
# 'Google AI Studio'
# 'GuviCertification - x69i3m212C421M6t06.png'
#  how-to-win-friends-and-influence-people.pdf
#  IMG_20210212_164310.jpg
# 'Infosys '
#  Janani
# 'Janani Certificates.pdf'
# 'Janani N'
# 'JEE Mains Formula Revision_ Class 12.pdf'
# 'jrh-cudb-jcx – 31 Mar 2024.pdf'
# ...

# %%
# !zip -r /content/drive/MyDrive/Synthia/synthia_app.zip /content/drive/MyDrive/Synthia
# Out:
#   adding: content/drive/MyDrive/Synthia/ (stored 0%)
#   adding: content/drive/MyDrive/Synthia/synthia.ipynb (deflated 87%)
#   adding: content/drive/MyDrive/Synthia/.ipynb_checkpoints/ (stored 0%)
#   adding: content/drive/MyDrive/Synthia/synthia.zip (stored 0%)
#   adding: content/drive/MyDrive/Synthia/agents/ (stored 0%)
#   adding: content/drive/MyDrive/Synthia/agents/__pycache__/ (stored 0%)
#   adding: content/drive/MyDrive/Synthia/agents/__pycache__/eda_agent.cpython-312.pyc (deflated 32%)
#   adding: content/drive/MyDrive/Synthia/agents/__pycache__/feed_agent.cpython-312.pyc (deflated 26%)
#   adding: content/drive/MyDrive/Synthia/agents/__pycache__/gan_agent.cpython-312.pyc (deflated 34%)
#   adding: content/drive/MyDrive/Synthia/agents/__pycache__/sample_gen_agent.cpython-312.pyc (deflated 31%)
#   adding: content/drive/MyDrive/Synthia/agents/__pycache__/__init__.cpython-312.pyc (deflated 22%)
# ...

# %%
from google.colab import files
files.download('synthia_app.zip')
